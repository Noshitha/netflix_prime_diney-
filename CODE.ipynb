# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dt=pd.read_csv("C:\\Users\\Dell\\Desktop\\time-series\\tv_shows.csv")

# %%
dt
# Out:
#       S.No                            Title  Year  Age  IMDb Rotten Tomatoes  \
# 0        0                     Breaking Bad  2008  18+   9.5             96%
# 1        1                  Stranger Things  2016  16+   8.8             93%
# 2        2                      Money Heist  2017  18+   8.4             91%
# 3        3                         Sherlock  2010  16+   9.1             78%
# 4        4                 Better Call Saul  2015  18+   8.7             97%
# ...    ...                              ...   ...  ...   ...             ...
# 5606  5606  Tut's Treasures: Hidden Secrets  2018  NaN   NaN             NaN
# 5607  5607                 Paradise Islands  2017  NaN   NaN             NaN
# 5608  5608                      Wild Russia  2018  NaN   NaN             NaN
# 5609  5609                      Love & Vets  2017  NaN   NaN             NaN
# 5610  5610         United States of Animals  2016  NaN   NaN             NaN
#
# ...

# %%
dt.drop(columns=["S.No"])
# Out:
#                                 Title  Year  Age  IMDb Rotten Tomatoes  \
# 0                        Breaking Bad  2008  18+   9.5             96%
# 1                     Stranger Things  2016  16+   8.8             93%
# 2                         Money Heist  2017  18+   8.4             91%
# 3                            Sherlock  2010  16+   9.1             78%
# 4                    Better Call Saul  2015  18+   8.7             97%
# ...                               ...   ...  ...   ...             ...
# 5606  Tut's Treasures: Hidden Secrets  2018  NaN   NaN             NaN
# 5607                 Paradise Islands  2017  NaN   NaN             NaN
# 5608                      Wild Russia  2018  NaN   NaN             NaN
# 5609                      Love & Vets  2017  NaN   NaN             NaN
# 5610         United States of Animals  2016  NaN   NaN             NaN
#
#       Netflix  Hulu  Prime Video  Disney+  type
# 0           1     0            0        0     1
# ...

# %%
dt.isnull().sum()
# Out:
# S.No                  0
# Title                 0
# Year                  0
# Age                2446
# IMDb               1161
# Rotten Tomatoes    4600
# Netflix               0
# Hulu                  0
# Prime Video           0
# Disney+               0
# type                  0
# dtype: int64

# %%
dt.mean()
# Out:
# S.No           2805.000000
# Year           2011.021030
# IMDb              7.113258
# Netflix           0.344145
# Hulu              0.312600
# Prime Video       0.382107
# Disney+           0.032080
# type              1.000000
# dtype: float64

# %%
dt.median()
# Out:
# S.No           2805.0
# Year           2015.0
# IMDb              7.3
# Netflix           0.0
# Hulu              0.0
# Prime Video       0.0
# Disney+           0.0
# type              1.0
# dtype: float64

# %%
dt.mode()
# Out:
#       S.No       Title    Year  Age  IMDb Rotten Tomatoes  Netflix  Hulu  \
# 0        0     Kingdom  2017.0  16+   7.4            100%      0.0   0.0
# 1        1  Undercover     NaN  NaN   NaN             NaN      NaN   NaN
# 2        2         NaN     NaN  NaN   NaN             NaN      NaN   NaN
# 3        3         NaN     NaN  NaN   NaN             NaN      NaN   NaN
# 4        4         NaN     NaN  NaN   NaN             NaN      NaN   NaN
# ...    ...         ...     ...  ...   ...             ...      ...   ...
# 5606  5606         NaN     NaN  NaN   NaN             NaN      NaN   NaN
# 5607  5607         NaN     NaN  NaN   NaN             NaN      NaN   NaN
# 5608  5608         NaN     NaN  NaN   NaN             NaN      NaN   NaN
# 5609  5609         NaN     NaN  NaN   NaN             NaN      NaN   NaN
# 5610  5610         NaN     NaN  NaN   NaN             NaN      NaN   NaN
#
#       Prime Video  Disney+  type
# 0             0.0      0.0   1.0
# ...

# %%
dt.Age = dt.Age.fillna('16+')

# %%
dt.IMDb=dt.IMDb.fillna('7.25')

# %%
dt['Rotten Tomatoes'] = dt['Rotten Tomatoes'].astype('str').str.rstrip('%').astype('float')
dt['Rotten Tomatoes'] = dt['Rotten Tomatoes'].fillna(0)

# %%
dt.describe()
# Out:
#               S.No         Year  Rotten Tomatoes      Netflix         Hulu  \
# count  5611.000000  5611.000000       5611.00000  5611.000000  5611.000000
# mean   2805.000000  2011.021030         13.96489     0.344145     0.312600
# std    1619.900511    11.005116         31.04382     0.475131     0.463594
# min       0.000000  1901.000000          0.00000     0.000000     0.000000
# 25%    1402.500000  2010.000000          0.00000     0.000000     0.000000
# 50%    2805.000000  2015.000000          0.00000     0.000000     0.000000
# 75%    4207.500000  2017.000000          0.00000     1.000000     1.000000
# max    5610.000000  2020.000000        100.00000     1.000000     1.000000
#
#        Prime Video      Disney+    type
# count  5611.000000  5611.000000  5611.0
# mean      0.382107     0.032080     1.0
# std       0.485946     0.176228     0.0
# min       0.000000     0.000000     1.0
# 25%       0.000000     0.000000     1.0
# 50%       0.000000     0.000000     1.0
# ...

# %% [markdown]
# # VISUALIZATIONS

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(12,8))
plt.title("Movies count over the years",fontsize=25)
sns.histplot(dt.Year);

# %% [markdown]
# As expected, the vast majority of the movies are from the last 20 years. However, it is also interesting to see that there is a significant amount of old movies in the catalogs too

# %%
Hulu_dt = dt.loc[(dt['Hulu'] > 0) ]
Disney_dt = dt.loc[(dt['Disney+'] > 0) ]
PrimeVideo_dt = dt.loc[(dt['Prime Video'] > 0)  ]
Netflix_dt = dt.loc[(dt['Netflix'] > 0)  ]

# %%
columns = ['Netflix', 'Hulu', 'Prime Video', 'Disney+']
ott_dt = dt[columns]
#Counting all values for each platform
ott = ott_dt.sum()
#Plotting into a bar plot using Seaborn
sns.set_style('darkgrid')
plt.figure(figsize=(10,8))
plt.title('Available Movies and TV Shows',fontsize=20)
sns.barplot(x=ott.index, y=ott.values);

# %% [markdown]
# Amazon prime video have majority of content followed by netflix while disney+ have the least content
